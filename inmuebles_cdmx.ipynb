# %% [markdown]
# <a href="https://colab.research.google.com/github/DevEnriquegd/Proyectos-Google-Colab/blob/main/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**

# %% [markdown]
# ## **Importando la base de datos**

# %%
import pandas as pd

url = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'

datos = pd.read_csv(url, sep=';')

datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
# Visualizar las 5 primeras filas

datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
# Visualizar las 5 últimas filas

datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
# Obtener una muestra de 10 filas

datos.sample(10)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 9785              Departamento              Santa Fe             2        1
# 3641              Departamento  Bosques de las Lomas             3        1
# 15066                     Casa             Nativitas             2        0
# 15638  Conjunto Comercial/Sala              Santa Fe             0        1
# 13339             Departamento             Nativitas             2        1
# 9914   Conjunto Comercial/Sala      Centro Histórico             0        1
# 24303             Departamento  Lomas de Chapultepec             4        2
# 24860             Departamento  Lomas de Chapultepec             2        0
# 9853              Departamento              Coyoacán             3        1
# 521               Departamento                  Roma             3        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 9785        1    93   8925.0      3465.0     595.0
# ...

# %%
# Saber el tipo de datos del archivo

type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
# Puedes leer diferentes archivos siguiendo la extensión de Pandas:
# Para CSV pd.read_csv()
# Para excel pd.read_excel()
# Para json pd.read_json()
# Para html pd.read_html()
# Para sql pd.read_sql()

# %% [markdown]
# ## **Exploración inicial de datos**

# %%
datos.sample(5)
# Out:
#                           Tipo                 Colonia  Habitaciones  Garages  \
# 3073              Departamento                Santa Fe             2        1
# 3479              Departamento  San Pedro de los Pinos             2        1
# 4288              Departamento    Lomas de Chapultepec             2        1
# 11658             Departamento                    Roma             2        1
# 22946  Conjunto Comercial/Sala              Peralvillo             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 3073        1    95   8575.0      5950.0       NaN
# 3479        0    90  10150.0      2852.5     336.0
# 4288        0    80  11200.0      5250.0     969.5
# 11658       1    73  11200.0      2282.0     304.5
# 22946       0    23   1575.0      1295.0     196.0

# %%
# Consultar el número de Filas y Columnas del archivo

datos.shape
# Out:
# (25121, 9)

# %%
# Consultar los encabezados de la tabla (columnas)

datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
# Obtener un resumen de las columnas, sus tipos y cuantos elementos contienen

datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
# Consultar los elementos de una columna

datos['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
# Consultar los elementos de n columnas

datos[['Tipo', 'Colonia']]
# Out:
#                           Tipo               Colonia
# 0                     Cocineta               Condesa
# 1                         Casa               Polanco
# 2      Conjunto Comercial/Sala              Santa Fe
# 3                 Departamento      Centro Histórico
# 4                 Departamento             Del Valle
# ...                        ...                   ...
# 25116  Cochera/Estacionamiento      Centro Histórico
# 25117                 Cocineta      Centro Histórico
# 25118             Departamento               Mixcoac
# 25119             Departamento  Lomas de Chapultepec
# 25120  Conjunto Comercial/Sala      Centro Histórico
#
# [25121 rows x 2 columns]

# %%
#Obtener los datos de la fila número 2

datos.iloc[2]
# Out:
# Tipo            Conjunto Comercial/Sala
# Colonia                        Santa Fe
# Habitaciones                          0
# Garages                               4
# Suites                                0
# Area                                150
# Valor                           18200.0
# Condominio                      14070.0
# Impuesto                         3888.5
# Name: 2, dtype: object

# %% [markdown]
# ## **Demandas de ML**

# %% [markdown]
# ### **Análisis exploratorio**

# %% [markdown]
# ####**¿Cuáles son los valores promedio de alquiler por tipo de propiedad?**

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos['Valor'].mean()
# Out:
# np.float64(36885.05048392878)

# %%
datos.groupby('Tipo').mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
datos.groupby('Tipo')[['Valor']].mean()
# Out:
#                                     Valor
# Tipo
# Casa                         31453.177064
# Casa Comercial               54735.841584
# Casa de Condominio           51428.609836
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Cocineta                      4425.856061
# Conjunto Comercial/Sala      57675.214550
# Departamento                 18683.269431
# Departamento en Hotel        16285.430769
# Edificio Completo           409418.080645
# Estudio                       8400.000000
# Galpón/Depósito/Almacén     299984.140138
# Hotel                        87500.000000
# Industria                   420000.000000
# Loft                          9924.526316
# Loteo/Condominio             92166.666667
# Posada/Chalé                  5180.000000
# Rancho                       38014.375000
# Terreno Estándar            135364.444444
# Tienda en Centro Comercial   32556.785714
# Tienda/Salón                 56263.544252

# %%
datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor', ascending=False)
# Out:
#                                     Valor
# Tipo
# Industria                   420000.000000
# Edificio Completo           409418.080645
# Galpón/Depósito/Almacén     299984.140138
# Terreno Estándar            135364.444444
# Loteo/Condominio             92166.666667
# Hotel                        87500.000000
# Conjunto Comercial/Sala      57675.214550
# Tienda/Salón                 56263.544252
# Casa Comercial               54735.841584
# Casa de Condominio           51428.609836
# Rancho                       38014.375000
# Tienda en Centro Comercial   32556.785714
# Casa                         31453.177064
# Departamento                 18683.269431
# Departamento en Hotel        16285.430769
# Loft                          9924.526316
# Estudio                       8400.000000
# Cochera/Estacionamiento       6995.454545
# Casa de Vecindad              5961.740506
# Posada/Chalé                  5180.000000
# Cocineta                      4425.856061

# %%
df_tipo_precio = datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor', ascending=True)

df_tipo_precio.plot(kind='barh', figsize=(12, 8),color='green')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# #### **¿Cuáles son los valores promedio de alquiler por tipo de propiedad no comerciales**

# %%
datos.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales = ['Conjunto Comercial/Sala', 'Edificio Completo', 'Tienda/Salón', 'Casa Comercial', 'Terreno Estándar', 'Cochera/Estacionamiento', 'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Hotel', 'Loteo/Condominio', 'Industria']

# %%
datos.query('@inmuebles_comerciales in Tipo')
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
datos.query('@inmuebles_comerciales not in Tipo')
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df = datos.query('@inmuebles_comerciales not in Tipo')

# %%
df_tipo_precio = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor', ascending=True)

df_tipo_precio.plot(kind='barh', figsize=(12, 8),color='green')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# #### **¿Cuál es el porcentaje de cada tipo de propiedad en nuestra base de datos?**

# %%
df.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
df.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
df.Tipo.value_counts(normalize=True).to_frame()
# Out:
#                        proportion
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058

# %%
porcentaje_inmuebles = df.Tipo.value_counts(normalize=True).to_frame()

porcentaje_inmuebles.plot(kind='bar', figsize=(12,8), color='blue', xlabel='Tipo de Inmueble', ylabel='Porcentaje')
# Out:
# <Axes: xlabel='Tipo de Inmueble', ylabel='Porcentaje'>

# %% [markdown]
# ### **Tratamiento de Valores nulos**

# %%
df.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 0      False    False         False    False   False  False  False
# 1      False    False         False    False   False  False  False
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 5      False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25114  False    False         False    False   False  False  False
# 25115  False    False         False    False   False  False  False
# 25117  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 0           False     False
# 1            True      True
# 3           False     False
# 4           False      True
# ...

# %%
df.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio      1155
# Impuesto        4645
# dtype: int64

# %%
df.fillna(0)
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df = df.fillna(0)

df.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# ### **Remover Valores inconsistentes**

# %%
df.query('Valor == 0 | Condominio == 0')
# Out:
#                      Tipo                 Colonia  Habitaciones  Garages  \
# 1                    Casa                 Polanco             2        0
# 5      Casa de Condominio                Santa Fe             5        4
# 7            Departamento        Centro Histórico             1        0
# 49           Departamento                Santa Fe             2        1
# 74           Departamento  Ciudad de los Deportes             2        0
# ...                   ...                     ...           ...      ...
# 25010    Casa de Vecindad                Doctores             3        0
# 25014        Departamento           Culhuacán CTM             3        0
# 25053    Casa de Vecindad    Santa Marta Acatitla             2        0
# 25086                Casa               Zacatenco             2        1
# 25099                Casa        Centro Histórico             5        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
df.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([    1,     5,     7,    49,    74,    78,    96,   116,   136,   154,
#        ...
#        24866, 24867, 24868, 24892, 24899, 25010, 25014, 25053, 25086, 25099],
#       dtype='int64', length=1162)

# %%
df_remover = df.query('Valor == 0 | Condominio == 0').index

# %%
df.drop(df_remover, axis=0,inplace=True)

# %%
df.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([], dtype='int64')

# %% [markdown]
# ### **Trabajar unicamente con los departamentos**

# %%
df = df.query('Tipo == "Departamento"')
df
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# 13     Departamento              Santa Fe             2        1       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df.drop('Tipo', axis=1, inplace=True)
df
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 10                  Condesa             4        3       1   243  45500.0
# 13                 Santa Fe             2        1       1    67   5950.0
# ...                     ...           ...      ...     ...   ...      ...
# 25111  Lomas de Chapultepec             3        0       1    80  10500.0
# 25113              Coyoacán             3        1       2   150  52500.0
# 25114              Narvarte             1        0       0    28   3500.0
# 25118               Mixcoac             2        1       0    48   4900.0
# 25119  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %% [markdown]
# ### **Creando Filtros**

# %% [markdown]
# #### **Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200.**

# %%
df.query('Habitaciones == 1 & Valor < 4200')
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
filtro1 = (df['Habitaciones'] == 1) & (df['Valor'] < 4200)
df1 = df[filtro1]

# %% [markdown]
# #### **Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².**

# %%
df.query('Habitaciones >= 2 & Valor < 10500 & Area > 70')
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          0.0
# 21          0.0
# ...

# %%
filtro2 = (df['Habitaciones'] >= 2) & (df['Valor'] < 10500) & (df['Area'] > 70)
df2 = df[filtro2]

# %% [markdown]
# ### **Guardando el DataFrame**

# %%
df.to_csv('inmuebles_ml.csv', index=False, sep=';')

# %%
df1.to_csv('inmuebles_ml_filtro1.csv', index=False, sep=';')
df2.to_csv('inmuebles_ml_filtro2.csv', index=False, sep=';')

# %%
pd.read_csv('inmuebles_ml.csv', sep=';')
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 0          Centro Histórico             1        0       0    15   2800.0
# 1                 Del Valle             1        0       0    48   2800.0
# 2                   Condesa             1        0       1    40   7000.0
# 3                   Condesa             4        3       1   243  45500.0
# 4                  Santa Fe             2        1       1    67   5950.0
# ...                     ...           ...      ...     ...   ...      ...
# 14259  Lomas de Chapultepec             3        0       1    80  10500.0
# 14260              Coyoacán             3        1       2   150  52500.0
# 14261              Narvarte             1        0       0    28   3500.0
# 14262               Mixcoac             2        1       0    48   4900.0
# 14263  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 0          1365.0      70.0
# ...

# %% [markdown]
# ## **Demandas de Devs**

# %%
datos = pd.read_csv(url, sep=';')

datos.shape
# Out:
# (25121, 9)

# %%
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %% [markdown]
# ### **Crer columnas numericas**

# %% [markdown]
# #### **valor_mensual: Esta columna debe contener los gastos mensuales de cada propiedad, incluyendo el alquiler y el condominio.**

# %%
datos['Valor mensual'] = datos['Valor'] + datos['Condominio']

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor mensual
# 0    40   5950.0      1750.0     210.0         7700.0
# 1   100  24500.0         NaN       NaN            NaN
# 2   150  18200.0     14070.0    3888.5        32270.0
# 3    15   2800.0      1365.0      70.0         4165.0
# 4    48   2800.0       805.0       NaN         3605.0

# %% [markdown]
# #### **valor_anual: Esta columna debe contener los gastos anuales por propiedad, es decir, el Impuesto más 12 meses de alquiler y condominio.**

# %%
datos['Valor anual'] = datos['Valor mensual'] * 12 + datos['Impuesto']

# %%
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto  Valor mensual  Valor anual
# 25116       0   755  49000.0         NaN       NaN            NaN          NaN
# 25117       0    27   2800.0      1225.0      87.5         4025.0      48387.5
# 25118       0    48   4900.0      1781.5     129.5         6681.5      80307.5
# 25119       0    70  10500.0      2660.0       NaN        13160.0          NaN
# 25120       0   250  22750.0     14721.0    3881.5        37471.0     453533.5

# %% [markdown]
# ### **Crear columnas categoricas**

# %% [markdown]
# #### **Descripcion: Esta columna debe contener un resumen de la información clave de las propiedades que se mostrarán en el sitio web: tipo de propiedad, barrio, cantidad de habitaciones y plazas de estacionamiento.**

# %%
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
# ...

# %%
datos['Descripcion'] = datos['Tipo'] + " ubicada en la colonia de " + datos['Colonia'] + " con un total de " + datos['Habitaciones'].astype(str) + " habitaciones y " + datos['Garages'].astype(str) + " plazas de estacionamiento."

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor mensual  Valor anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                          Descripcion
# ...

# %%
datos.iloc[500].Descripcion
# Out:
# 'Departamento ubicada en la colonia de Napoles con un total de 1 habitaciones y 0 plazas de estacionamiento.'

# %% [markdown]
# #### **Tiene_suite: Esta debe ser una columna que indique únicamente si la propiedad tiene o no suites, sin importar la cantidad.**

# %%
datos['Tiene suite'] = datos['Suites'].apply(lambda x: 'Si' if x > 0 else 'No')

# %%
datos.sample(5)
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 961               Departamento           Condesa             1        0
# 11214             Departamento              Roma             1        0
# 1790              Departamento          Santa Fe             2        1
# 14326             Departamento          Santa Fe             1        1
# 18179  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto  Valor mensual  \
# 961         0    25   7000.0         NaN       NaN            NaN
# 11214       0    43   8400.0      3766.0     910.0        12166.0
# 1790        1    70   7700.0      2730.0       NaN        10430.0
# 14326       1    62   5250.0      3780.0     913.5         9030.0
# 18179       0   200  52500.0     17045.0    4672.5        69545.0
#
#        Valor anual                                        Descripcion  \
# ...

# %%
datos.to_csv('inmuebles_dev.csv', index=False, sep=';')
